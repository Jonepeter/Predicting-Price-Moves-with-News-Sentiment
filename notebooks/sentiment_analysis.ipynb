# %%
import os
import sys
if not os.path.abspath("..") in sys.path:
    sys.path.append(os.path.abspath(".."))

# %%
# %load_ext autoreload
# %autoreload 2
from scripts.util_sentiment import MovieNewsSentiment

# %%
explore = MovieNewsSentiment()
data = explore.load_data("../data/raw_analyst_ratings.csv", "date")
# Out:
# Data loaded successfully.

# %% [markdown]
# ### Descriptive Statistics
# - Objective
#   - Find headline length and describe its statistics
#   - Identifying which publisher is active
#   - Analyze publication date

# %%
# analyze headline length 
explore.analyze_headline_lengths()
# Out:
#  Headline Length Statistics:
#  count    1407328
# mean          73
# std           40
# min            3
# 25%           47
# 50%           64
# 75%           87
# max          512
# Name: headline_length, dtype: int64

# %%
# find number of articles by publisher 
explore.count_articles_by_publisher()
# Out:
# Articles per Publisher:
#  publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
#                       ...
# MoneyGeek                 1
# muathe                    1
# Robert Morris             1
# LeftCoastHedgie           1
# Jeremie Capron            1
# Name: count, Length: 1034, dtype: int64

# %%
# find visualize number of publication in each dates and days of the week
explore.analyze_publication_dates()
# Out:
# Articles per Date:
#  date
# 2009-02-14      1
# 2009-04-27      2
# 2009-04-29      1
# 2009-05-22      1
# 2009-05-27      6
#              ...
# 2020-06-07     25
# 2020-06-08    765
# 2020-06-09    804
# 2020-06-10    806
# 2020-06-11    544
# Name: count, Length: 3955, dtype: int64
# Articles by Day of the Week:
#  day_of_week
# Thursday     302595
# Wednesday    300940
# Tuesday      296470
# Monday       265164
# Friday       217892
# Sunday        16514
# Saturday       7753
# Name: count, dtype: int64

# %% [markdown]
# ### **Text analysis (Topic Modeling)**
# - Objective
#   - Identify common keywords phrases from the headlines

# %%
# tokenzationa and removing stop words
explore.preprocess_text()
# Out:
# Preprocessing completed.

# %%
# Extracting most frequent terms from headlines  
explore.extract_keywords()
# Out:
# Top Keywords (TF-IDF):
# stocks: 40107.5126
# est: 33540.1372
# eps: 27330.1244
# earnings: 26783.4158
# benzingas: 26169.6400
# reports: 22237.0634
# week: 21236.1598
# downgrades: 20694.2281
# market: 20474.4986
# upgrades: 19982.8539

# %%
# Applying LDA topic modeling and extracting top 30 topics 
explore.perform_topic_modeling()
# Out:
# Top 30 Topics:
# Topic 1: higher | cramer | spikes | shares | trading
# Topic 2: contract | says | forexlive | awarded | wins
# Topic 3: piper | jaffray | overweight | regional | brands
# Topic 4: goldman | sachs | buy | neutral | point
# Topic 5: set | new | week | stocks | yesterday
# Topic 6: est | eps | reports | sales | sees
# Topic 7: coverage | initiates | morgan | announces | stanley
# Topic 8: losers | morning | market | premarket | benzinga
# Topic 9: initiations | benzingas | preview | eps | est
# Topic 10: bank | buy | downgrades | maintains | hold
# Topic 11: biggest | movers | yesterday | friday | chatter
# Topic 12: bancorp | sterne | agee | pops | electronic
# Topic 13: industry | highest | stocks | smallcap | nyse
# Topic 14: phase | fda | biotech | trial | daily
# Topic 15: halted | stake | minutes | roundup | pending
# Topic 16: gainers | market | shares | premarket | news
# Topic 17: wells | fargo | notable | options | activity
# ...

# %% [markdown]
# ### Time series analysis

# %%
# Explore frequency of publication per days 
explore.publication_by_day()

# %%
# Exploring publications per Hours 
explore.publication_by_hour()

# %% [markdown]
# ### Publisher analysis

# %%
explore.top_publishers()
# Out:
# ----------- Top 10 ------------
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64

# %%
explore.extract_email_domain()
# Out:
# publisher
# None                      1399240
# benzinga.com                 7937
# gmail.com                     139
# andyswan.com                    5
# investdiva.com                  2
# tothetick.com                   2
# eosdetroit.io                   1
# forextraininggroup.com          1
# stockmetrix.net                 1
# Name: count, dtype: int64
