# %% [markdown]
# ## **Task 2: Quantitative analysis using pynance and TaLib**

# %%
# Import required libraries 
import os 
import sys
sys_path = os.path.abspath("../")
if sys_path not in sys.path:
    sys.path.append(sys_path)
    
# enable autoreload    
# %load_ext autoreload
# %autoreload 2
from scripts.util_price_analysis import StockPriceAnalyzer 
from scripts.finance_indicator_util import QuantitativeAnalyzer
from scripts.Stock_Analysis import fetch_data, calculate_technical_indicators, calculate_financial_metrics, visualize_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = fetch_data()
# Out:
# INFO:root:--------- Fetching data for Stock Price Analysis -----------
# INFO:root:Combined 7 files into one DataFrame with 45428 rows.
# INFO:root:Data loaded successfully

# %%
calculate_technical_indicators(data)
# Out:
# Calculating technical indicators...
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 45423  2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 45424  2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 45425  2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 45426  2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
# ...

# %%
visualize_data(data)
# Out:
# Generating visualizations...
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
analysis = StockPriceAnalyzer()

# %%
analysis.fetch_data()
# Out:
# INFO:scripts.util_price_analysis:--------- Fetching data for Stock Price Analysis -----------
# INFO:scripts.util_price_analysis:Combined 7 files into one DataFrame with 45428 rows.
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#    Dividends  Stock Splits Ticker
# 0        0.0           0.0   AAPL
# 1        0.0           0.0   AAPL
# 2        0.0           0.0   AAPL
# 3        0.0           0.0   AAPL
# 4        0.0           0.0   AAPL
# 'Successfully fetched 45428 rows of data'

# %%
analysis.calculate_indicators()
# Out:
# INFO:scripts.util_price_analysis:Successfully calculated technical indicators
#            SMA_20    SMA_50    SMA_200     RSI_14       MACD  MACD_Signal  \
# 0             NaN       NaN        NaN        NaN        NaN          NaN
# 1             NaN       NaN        NaN        NaN        NaN          NaN
# 2             NaN       NaN        NaN        NaN        NaN          NaN
# 3             NaN       NaN        NaN        NaN        NaN          NaN
# 4             NaN       NaN        NaN        NaN        NaN          NaN
# ...           ...       ...        ...        ...        ...          ...
# 45423  237.924999  202.1838  205.24100  44.886918  11.789291    15.873789
# 45424  239.118999  203.1510  205.03960  46.951389   9.353206    14.569672
# 45425  240.238000  203.9960  204.84025  46.752165   7.302106    13.116159
# 45426  241.949000  205.1582  204.68265  52.664511   6.593101    11.811547
# 45427  242.587000  206.1138  204.48080  48.220474   5.206237    10.490485
#
# ...

# %%
analysis.calculate_sma(20)
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 45423    237.924999
# 45424    239.118999
# 45425    240.238000
# 45426    241.949000
# 45427    242.587000
# Length: 45428, dtype: float64

# %%
import pandas as pd

# %%
pd.read_csv("../data/yfinance_data/yfinance_data/AMZN_historical_data.csv")
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6841  2024-07-24  183.199997  185.449997  180.410004  180.830002  180.830002
# 6842  2024-07-25  182.910004  183.899994  176.800003  179.850006  179.850006
# 6843  2024-07-26  180.389999  183.190002  180.240005  182.500000  182.500000
# 6844  2024-07-29  183.839996  184.750000  182.380005  183.199997  183.199997
# 6845  2024-07-30  184.720001  185.860001  179.380005  181.710007  181.710007
#
#           Volume  Dividends  Stock Splits
# ...

# %%
import glob
import logging as logger
data_folder = "../data/yfinance_data/yfinance_data/"
csv_files = glob.glob(os.path.join(data_folder, "*.csv"))

if not csv_files:
    logger.error(f"No CSV files found in {data_folder}")

list_annotation = ['AAPL', 'AMZN', 'GOOG', 'META', 'MSTF', 'NVDA', 'TSLA']
list_data = [pd.read_csv(file) for file in csv_files]
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 10993  2024-07-24  224.000000  224.800003  217.130005  218.539993  218.287323
# 10994  2024-07-25  218.929993  220.850006  214.619995  217.490005  217.238556
# 10995  2024-07-26  218.699997  219.490005  216.009995  217.960007  217.708008
# 10996  2024-07-29  216.960007  219.300003  215.750000  218.240005  217.987686
# 10997  2024-07-30  219.190002  220.330002  216.119995  218.800003  218.547043
#
# ...

# %%
combined_data = pd.concat(list_data, ignore_index=True)

# %%
f = QuantitativeAnalyzer()

# %%
f.fetch_data()
# Out:
# INFO:root:--------- Fetching data for Stock Price Analysis -----------
# INFO:root:Combined 7 files into one DataFrame with 45428 rows.
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#    Dividends  Stock Splits Ticker
# 0        0.0           0.0   AAPL
# 1        0.0           0.0   AAPL
# 2        0.0           0.0   AAPL
# 3        0.0           0.0   AAPL
# 4        0.0           0.0   AAPL
# 'Successfully fetched 45428 rows of data'

# %%
f.clean_data()
# Out:
# INFO:root:Cleaning and preparing data
# INFO:root:Data cleaning completed

# %%
f.calculate_technical_indicators()
# Out:
# Calculating technical indicators...
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 45423  2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 45424  2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 45425  2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 45426  2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
# ...

# %%
f.calculate_financial_metrics()
# Out:
# Calculating financial metrics...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 f.calculate_financial_metrics()
#
# File e:\Courses\10 Academy\Week 1\Predicting-Price-Moves-with-News-Sentiment\scripts\finance_indicator_util.py:271, in QuantitativeAnalyzer.calculate_financial_metrics(self)
#     269 print("Calculating financial metrics...")
#     270 # Daily returns
# --> 271 daily_returns = pn.data.returns(self.data['Close'])
#     273 # Annualized volatility
#     274 volatility = pn.volatility.annualized(daily_returns, periods=252)
#
# AttributeError: module 'pynance.data' has no attribute 'returns'

# %%
import nltk
# Verify punkt tokenizer availability
try:
    nltk.data.find('tokenizers/punkt')
    print("Local punkt tokenizer found.")
except LookupError:
    print("Error: punkt tokenizer not found in ./nltk_data. Please download it using nltk.download('punkt', download_dir='./nltk_data').")
    exit(1)
# Out:
# Local punkt tokenizer found.

# %%
import nltk
from nltk.tokenize import word_tokenize
text = "Apple hits all-time high. Analysts raise price target."
print(word_tokenize(text.lower()))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[48], line 4
#       2 from nltk.tokenize import word_tokenize
#       3 text = "Apple hits all-time high. Analysts raise price target."
# ----> 4 print(word_tokenize(text.lower()))
#
# File c:\Users\jonep\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# ...
